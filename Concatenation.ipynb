# %%
354972062885738, 354972062885746,354972062885753,354972062886561,354972062886587,354972062886595,354972062886611
# Out:
# (354972062885738,
#  354972062885746,
#  354972062885753,
#  354972062886561,
#  354972062886587,
#  354972062886595,
#  354972062886611)

# %%
data_list=[354972062885738, 354972062885746,354972062885753,354972062886561,354972062886587,354972062886595,354972062886611]

# %%
df_list=[]
for each in data_list:
    df="Data_"+str(each)+".csv"
    df_list.append(df)
df_list
# Out:
# ['Data_354972062885738.csv',
#  'Data_354972062885746.csv',
#  'Data_354972062885753.csv',
#  'Data_354972062886561.csv',
#  'Data_354972062886587.csv',
#  'Data_354972062886595.csv',
#  'Data_354972062886611.csv']

# %%
import pandas as pd
dataframes_list=[]
for each in df_list:
    dataframes_list.append(pd.read_csv(each))
# Out:
# C:\Users\INFO-DSK-04\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import numpy as np
lst=[]
for each in dataframes_list:
    print(each.shape)
    lst.append(each.shape)
np.sum(pair[0] for pair in lst)
# Out:
# (20587, 31)
# (15295, 31)
# (7592, 31)
# (69900, 31)
# (56668, 31)
# (3238, 31)
# (3275, 31)
# C:\Users\INFO-DSK-04\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# 176555

# %%
Full_data = pd.concat(list(dataframes_list))
Full_data.to_csv("Full_data.csv")

# %%
Full_data.head()
# Out:
#    SlNo   AssetNo         DeviceNo  Latitude  Longitude  Altitude  Speed  \
# 0     1  VIT_5738  354972062885738  19.12572   73.01328      83.0      0
# 1     2  VIT_5738  354972062885738  19.12670   73.01229       6.5      0
# 2     3  VIT_5738  354972062885738  19.12671   73.01226       8.8      2
# 3     4  VIT_5738  354972062885738  19.12671   73.01226       NaN      2
# 4     5  VIT_5738  354972062885738  19.12670   73.01225       6.2      0
#
#    Satellite            TrackDateTime  Direction  \
# 0          5  2019-09-18 17:33:23.000          0
# 1          6  2019-09-24 11:11:02.000          0
# 2          6  2019-09-24 11:11:15.000          0
# 3          6  2019-09-24 11:11:15.000          0
# 4         14  2019-09-24 11:12:02.000          0
#
#                          ...                         SoftwareVersion  \
# 0                        ...                                    5602
# 1                        ...                                    5602
# ...

# %%
Full_data.columns
# Out:
# Index(['SlNo', 'AssetNo', 'DeviceNo', 'Latitude', 'Longitude', 'Altitude',
#        'Speed', 'Satellite', 'TrackDateTime', 'Direction', 'Location',
#        'GeofenceName', 'MessageNumber', 'OdoMeter', 'Ignition', 'Digital1',
#        'Digital2', 'Digital3', 'Digital4', 'Analog1', 'Analog2',
#        'SoftwareVersion', 'RoadSpeed', 'DriverId', 'FuelinLtrs', 'EngineRpm',
#        'IbuttonId', 'UpdationTime', 'SqncNumber', 'OdometerLL',
#        'AdditionalData'],
#       dtype='object')

# %%
reqd_data=Full_data[['AssetNo', 'DeviceNo', 'Latitude', 'Longitude','Speed', 'Altitude','TrackDateTime', 'Ignition']]
reqd_data['AlertType']=np.nan
reqd_data['left']=1
# Out:
# C:\Users\INFO-DSK-04\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\INFO-DSK-04\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
reqd_data.head()
# Out:
#     AssetNo         DeviceNo  Latitude  Longitude  Speed  Altitude  \
# 0  VIT_5738  354972062885738  19.12572   73.01328      0      83.0
# 1  VIT_5738  354972062885738  19.12670   73.01229      0       6.5
# 2  VIT_5738  354972062885738  19.12671   73.01226      2       8.8
# 3  VIT_5738  354972062885738  19.12671   73.01226      2       NaN
# 4  VIT_5738  354972062885738  19.12670   73.01225      0       6.2
#
#              TrackDateTime  Ignition  AlertType  left
# 0  2019-09-18 17:33:23.000         0        NaN     1
# 1  2019-09-24 11:11:02.000         0        NaN     1
# 2  2019-09-24 11:11:15.000         0        NaN     1
# 3  2019-09-24 11:11:15.000         0        NaN     1
# 4  2019-09-24 11:12:02.000         0        NaN     1

# %%
alert_data=pd.read_csv("Devices with Alerts.csv")

# %%
alert_data.columns
# Out:
# Index(['AlertType', 'AssetNo', 'DeviceNo', 'Latitude', 'Longitude', 'Location',
#        'GeofenceName', 'Speed', 'Remarks', 'SimNos', 'Message',
#        'AlertDatetime', 'SMSDatetime', 'FuelBarStatus',
#        'FuelBarClosedDatetime', 'SendStatus', 'AlertStatus', 'Latitude2',
#        'Longitude2', 'Location2', 'GeofenceName1', 'GeofenceName2', 'MialId',
#        'TrackDateTime', 'Ignition', 'AttendedBy', 'AttendedTime',
#        'AttendedStatus', 'DeviceSendStatus', 'DeviceMobileNo', 'FcmSentStatus',
#        'ACKStatus', 'AdditionalData', 'MsgType', 'MsgSlno', 'SEMMessage',
#        'SEMResponse', 'SEMSendTime', 'SEMResponseTime',
#        'NotificationSendStatus', 'SensorID', 'SensorName', 'DisplayName',
#        'ExSlno'],
#       dtype='object')

# %%
alert_data.drop("TrackDateTime",axis=1,inplace=True)

# %%
alert_data.rename(columns={"AlertDatetime":"TrackDateTime"},inplace=True)

# %%
alerts=alert_data[['AssetNo', 'DeviceNo', 'Latitude', 'Speed', 'Longitude','TrackDateTime', 'Ignition','AlertType']]
alerts['Altitude']=np.nan
alerts['left']=0
# Out:
# C:\Users\INFO-DSK-04\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\INFO-DSK-04\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
alerts.head()
alerts.shape
# Out:
# (741, 10)

# %%
# import datetime
# d = datetime.datetime.strptime('2011-06-09', '%Y-%m-%d')
# d.strftime('%b %d,%Y')
# 'Jun 09,2011'

# %%
reqd_data.TrackDateTime.head()
# Out:
# 0    2019-09-18 17:33:23.000
# 1    2019-09-24 11:11:02.000
# 2    2019-09-24 11:11:15.000
# 3    2019-09-24 11:11:15.000
# 4    2019-09-24 11:12:02.000
# Name: TrackDateTime, dtype: object

# %%
Complete_data = pd.concat([reqd_data, alerts], ignore_index=True, sort=False).sort_values([ 'TrackDateTime'])
Complete_data["AlertTypeName"]=Complete_data.AlertType
Complete_data=Complete_data.replace({'AlertTypeName': {32: "Rash Turning", 14: "Harsh Breaking",15: "Harsh Acceleration"}})

# %%
Complete_data.to_csv("Complete_data.csv",index=False)

# %%
Complete_data
# Out:
#             AssetNo         DeviceNo  Latitude  Longitude  Speed  Altitude  \
# 177233     VIT_5738  354972062885738   0.00000    0.00000      0       NaN
# 177234     VIT_5738  354972062885738   0.00000    0.00000      0       NaN
# 177252     VIT_5738  354972062885738   0.00000    0.00000      0       NaN
# 177253     VIT_5738  354972062885738   0.00000    0.00000      0       NaN
# 177254     VIT_5738  354972062885738   0.00000    0.00000      0       NaN
# 177255     VIT_5738  354972062885738  19.12602   73.01448      1       NaN
# 177235     VIT_5738  354972062885738  19.12586   73.01430      3       NaN
# 177236     VIT_5738  354972062885738  19.12623   73.01284      9       NaN
# 177237     VIT_5738  354972062885738   0.00000    0.00000      0       NaN
# 177238     VIT_5738  354972062885738   0.00000    0.00000      0       NaN
# 177239       DNI753  354972062885753  19.12509   73.01510      2       NaN
# ...
